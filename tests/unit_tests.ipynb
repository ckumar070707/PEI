# %% [markdown]
# # Tests : nulls, empty, duplicates

# %%
import pytest
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType, LongType

# %%
enriched_orders_path = "/Volumes/workspace/default/enriched/Orders"
enriched_customers_path = "/Volumes/workspace/default/enriched/Customers"
enriched_products_path = "/Volumes/workspace/default/enriched/Products"
agg_profit_path = "/Volumes/workspace/default/enriched/Profit"

# %%
@pytest.fixture(scope="session")
def test_profit_rounding_and_schema():
    orders = spark.read.format("delta").load(enriched_orders_path)
    customers = spark.read.format("delta").load(enriched_customers_path)
    products = spark.read.format("delta").load(enriched_products_path)
    agg_profit = spark.read.format("delta").load(agg_profit_path)
