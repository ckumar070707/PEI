# %%
def Customer_transform(raw_path,transform_path):
    try:
        #pd_df_raw = spark.read.format("com.crealytics.spark.excel").option("header","true").option("inferSchema","true").load(raw_path)
        df_raw = pd.read_excel(raw_path)
        df_raw = spark.createDataFrame(df_raw)
        df_raw.display()
    except Exception as e:
        print(f"somethign went wroing {e}")

# %%
df = (spark.read
      .format("com.crealytics.spark.excel")
      .option("header", "true")
      .option("inferSchema", "true")
      .load("/FileStore/tables/input.xlsx"))

# %%
pip install openpyxl

# %%
# %restart_python

# %%
import pandas as pd

pdf = pd.read_excel("/dbfs/FileStore/tables/myfile.xlsx")
df = spark.createDataFrame(pdf)

# %%
import pandas as pd

raw_path = '/Volumes/workspace/default/raw/Customer.xlsx'
transform_path = "/Volumes/workspace/default/transformed/Customer"
Customer_transform(raw_path,transform_path)
