# %%
source_location = "/Volumes/workspace/default/pei_drive"
raw_location = "/Volumes/workspace/default/raw"
transform_location = "/Volumes/workspace/default/transformed"
enriched_location = "/Volumes/workspace/default/enriched"
ingestion_config = {}
transform_config = {}

# %%
ingestion_config['Products'] = {'source_path': source_location + '/Products.csv', 
                                'raw_path': raw_location + '/Products.csv'}
transform_config['Products'] = {'transform_path': transform_location + '/Products'}

# %%
ingestion_config['Orders'] = {'source_path': source_location + '/Orders.json', 
                                'raw_path': raw_location + '/Orders.json'}
transform_config['Orders'] = {'transform_path': transform_location + '/Orders'}

# %%
ingestion_config['Customer'] = {'source_path': source_location + '/Customer.xlsx', 
                                'raw_path': raw_location + '/Customer.xlsx'}
transform_config['Customer'] = {'transform_path': transform_location + '/Customer'}
