# %%
csv_path = "/Volumes/workspace/default/pei_volumne/Products.csv"

# %%
#read csv from a link
df = spark.read.option("header", True).option("inferSchema","True").option("escape",'"').csv("/Volumes/workspace/default/pei_drive/Products.csv")
df.printSchema()
display(df)

# %%
df_json = spark.read.option("multiLine", True).json("/Volumes/workspace/default/raw/Orders.json")
df_json.printSchema()
display(df_json.limit(100))

# %%
# %sql
select * from delta.`/Volumes/workspace/default/enriched/Customers`

# %%
# %sql
select * from delta.`/Volumes/workspace/default/enriched/Products`

# %%
# %sql
select * from delta.`/Volumes/workspace/default/enriched/Orders`

# %%
# %sql
select * from delta.`/Volumes/workspace/default/enriched/Profit` limit 5 -- order by 4,1

# %%
# %sql
select * from delta.`/Volumes/workspace/default/transformed/Orders`

# %%
# %sql
SELECT year,round(sum(Total_Profit),2) as total_profit from delta.`/Volumes/workspace/default/enriched/Profit` GROUP BY Year ORDER BY Year

# %%
# %sql
SELECT year,Product_Category,round(sum(Total_Profit),2) as total_profit from delta.`/Volumes/workspace/default/enriched/Profit` GROUP BY Year,Product_Category ORDER BY Year,Product_Category

# %%
# %sql
SELECT Customer_Name,round(sum(Total_Profit),2) as total_profit from delta.`/Volumes/workspace/default/enriched/Profit` GROUP BY Customer_Name ORDER BY Customer_Name

# %%
# %sql
SELECT Customer_Name,Year,round(sum(Total_Profit),2) as total_profit from delta.`/Volumes/workspace/default/enriched/Profit` GROUP BY Customer_Name,Year ORDER BY Customer_Name,Year
