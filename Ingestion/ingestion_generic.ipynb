# %%
dbutils.widgets.text("source_object_name","")
dbutils.widgets.text("load_type","")

# %%
#get the source object name, load_type,
soure_object_name = dbutils.widgets.get("source_object_name")
load_type = dbutils.widgets.get("load_type")

# %%
#run the paramater file
# %run ../config/params.ipynb

# %%
#get the object details: 
try:
    source_path = ingestion_config[soure_object_name].get("source_path")
    raw_path  = ingestion_config[soure_object_name].get("raw_path")

except Exception as e:
    print(f"Error while retrieving object details from params: {e}")

# %%
#copy the file from source to raw
try:
    dbutils.fs.cp(source_path, raw_path, recurse=True)
except Exception as e:
    print(f"Error while copying file from source to raw: {e}")
